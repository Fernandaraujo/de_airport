# %%
from pyspark.sql import SparkSession, functions as F

# %%
spark = SparkSession.builder.getOrCreate()

# %% [markdown]
# ## Carregar dos dados de AIR_CIA

# %%
df_aircia = spark.read.csv('bronze/AIR_CIA/', sep=';', header=True)

# %%
df_aircia.show(vertical=True)
# Out:
# -RECORD 0----------------------------------------
#  Razão Social             | ABSA - AEROLINHAS...
#  ICAO IATA                | LTG M3
#  CNPJ                     | 00.074.635/0001-33
#  Atividades Aéreas        | TRANSPORTE AÉREO ...
#  Endereço Sede            | AEROPORTO INTERNA...
#  Telefone                 | (11) 5582-8055
#  E-Mail                   | gar@tam.com.br
#  Decisão Operacional      | DECISÃO Nº 41
#  Data Decisão Operacional | 22/04/2015
#  Validade Operacional     | 23/04/2025
# -RECORD 1----------------------------------------
#  Razão Social             | AEROSUL TÁXI AÉRE...
#  ICAO IATA                | ASO 2S
#  CNPJ                     | 27.315.694/0001-02
#  Atividades Aéreas        | SERVIÇOS AÉREOS P...
#  Endereço Sede            | RODOVIA PR 218, K...
#  Telefone                 | (43) 3176-4030
#  E-Mail                   | operacoes@aerosul...
#  Decisão Operacional      | DECISÃO Nº 282
#  Data Decisão Operacional | 10/02/2021
#  Validade Operacional     | null
# -RECORD 2----------------------------------------
#  Razão Social             | ASTA LINHAS AÉREA...
#  ICAO IATA                | SUL 0A
#  CNPJ                     | 12.703.737/0001-50
#  Atividades Aéreas        | SERVIÇOS AÉREOS P...
#  Endereço Sede            | AV GOVERNADOR JOÃ...
#  Telefone                 | (65) 3614-2684 / ...
#  E-Mail                   | null
#  Decisão Operacional      | DECISÃO Nº 115
#  Data Decisão Operacional | 31/07/2019
#  Validade Operacional     | 02/08/2024
# -RECORD 3----------------------------------------
#  Razão Social             | ATA - AEROTÁXI AB...
#  ICAO IATA                | ABJ
#  CNPJ                     | 14.674.451/0001-19
#  Atividades Aéreas        | TÁXI-AÉREO, TRANS...
#  Endereço Sede            |  PÇA. GAGO COUTIN...
#  Telefone                 | (71) 34629600 / (...
#  E-Mail                   | guilherme@abaete....
#  Decisão Operacional      | DECISÃO Nº 36
#  Data Decisão Operacional | 05/03/2020
#  Validade Operacional     | null
# -RECORD 4----------------------------------------
#  Razão Social             | AZUL CONECTA LTDA...
#  ICAO IATA                | ACN 2F
#  CNPJ                     | 04.263.318/0001-16
#  Atividades Aéreas        | TRANSPORTE AÉREO ...
#  Endereço Sede            | AVENIDA EMILIO AN...
#  Telefone                 | (11) 45822355/ (1...
#  E-Mail                   | null
#  Decisão Operacional      | Decisão nº 14, de...
#  Data Decisão Operacional | 25/01/2018
#  Validade Operacional     | 29/01/2028
# -RECORD 5----------------------------------------
#  Razão Social             | AZUL LINHAS AÉREA...
#  ICAO IATA                | AZU AD
#  CNPJ                     | 09.296.295/0001-60
#  Atividades Aéreas        | TRANSPORTE AÉREO ...
#  Endereço Sede            | AV. MARCOS PENTEA...
#  Telefone                 |  (55) (11) 4134-9...
#  E-Mail                   | vanessa.reis@voea...
#  Decisão Operacional      | Decisão nº 178
#  Data Decisão Operacional | 20/11/2018
#  Validade Operacional     | 21/11/2028
# -RECORD 6----------------------------------------
#  Razão Social             | GOL LINHAS AÉREAS...
#  ICAO IATA                | GLO G3
#  CNPJ                     | 07.575.651/0001-59
#  Atividades Aéreas        | TRANSPORTE AÉREO ...
#  Endereço Sede            | PRAÇA SENADOR SAL...
#  Telefone                 | (11) 5098-2990 / ...
#  E-Mail                   | rddfonseca@voegol...
#  Decisão Operacional      | DECISÃO Nº 156
#  Data Decisão Operacional | 05/11/2019
#  Validade Operacional     | null
# -RECORD 7----------------------------------------
#  Razão Social             | MAP TRANSPORTES A...
#  ICAO IATA                | PAM 7M
#  CNPJ                     | 10.483.635/0001-40
#  Atividades Aéreas        | TRANSPORTE AÉREO ...
#  Endereço Sede            | AVENIDA SANTOS DU...
#  Telefone                 | (92) 36521620
#  E-Mail                   | contabil@voemap.c...
#  Decisão Operacional      | DECISÃO Nº 89
#  Data Decisão Operacional | 14/08/2012
#  Validade Operacional     | 17/08/2022
# -RECORD 8----------------------------------------
#  Razão Social             | MODERN TRANSPORTE...
#  ICAO IATA                | MWM WD
#  CNPJ                     | 03.887.831/0001-15
#  Atividades Aéreas        | TRANSPORTE AÉREO ...
#  Endereço Sede            | AVENIDA PREFEITO ...
#  Telefone                 | (21) 2272-9272 / ...
#  E-Mail                   | juridico@modern.c...
#  Decisão Operacional      | DECISÃO Nº 79
#  Data Decisão Operacional | 31/05/2017
#  Validade Operacional     | 02/06/2027
# -RECORD 9----------------------------------------
#  Razão Social             | PASSAREDO TRANSPO...
#  ICAO IATA                | PTB 2Z
#  CNPJ                     | 00.512.777/0001-35
#  Atividades Aéreas        | TRANSPORTE AÉREO ...
#  Endereço Sede            | SETOR DE HANGARES...
#  Telefone                 | (16) 3514-7127 / ...
#  E-Mail                   | juridico@voepass....
#  Decisão Operacional      | DECISÃO Nº 105
#  Data Decisão Operacional | 09/06/2020
#  Validade Operacional     | null
# -RECORD 10---------------------------------------
#  Razão Social             | SIDERAL LINHAS AÉ...
#  ICAO IATA                | SID 0S
#  CNPJ                     | 10.919.908/0001-57
#  Atividades Aéreas        | TRANSPORTE AÉREO ...
#  Endereço Sede            | RODOVIA CONTORNO ...
#  Telefone                 | (41) 3116-9000 / ...
#  E-Mail                   | office@siderallin...
#  Decisão Operacional      | DECISÃO Nº 37
#  Data Decisão Operacional | 05/03/2020
#  Validade Operacional     | 06/03/2025
# -RECORD 11---------------------------------------
#  Razão Social             | TAM LINHAS AÉREAS...
#  ICAO IATA                | TAM JJ
#  CNPJ                     | 02.012.862/0001-60
#  Atividades Aéreas        | TRANSPORTE AÉREO ...
#  Endereço Sede            | RUA ÁTICA , N° 67...
#  Telefone                 | (11) 5582-8055 / ...
#  E-Mail                   | gar@tam.com.br
#  Decisão Operacional      | DECISÃO Nº 366
#  Data Decisão Operacional | 07/07/2021
#  Validade Operacional     | 09/11/2031
# -RECORD 12---------------------------------------
#  Razão Social             | TOTAL LINHAS AÉRE...
#  ICAO IATA                | TTL L1
#  CNPJ                     | 32.068.363/0001-55
#  Atividades Aéreas        | SERVIÇOS AÉREOS P...
#  Endereço Sede            | AV. SENADOR SALGA...
#  Telefone                 | (41) 3371-8200 / ...
#  E-Mail                   | geraldo.antonio@t...
#  Decisão Operacional      | DECISÃO Nº 260
#  Data Decisão Operacional | 12/01/2021
#  Validade Operacional     | 14/01/2031
# -RECORD 13---------------------------------------
#  Razão Social             | AEROSUL TÁXI AÉRE...
#  ICAO IATA                | ASO 2S
#  CNPJ                     | 27.315.694/0001-02
#  Atividades Aéreas        | SERVIÇOS AÉREOS P...
#  Endereço Sede            | RODOVIA PR 218, K...
#  Telefone                 | (43) 3176-4030
#  E-Mail                   | operacoes@aerosul...
#  Decisão Operacional      | DECISÃO Nº 282
#  Data Decisão Operacional | 10/02/2021
#  Validade Operacional     | null
# -RECORD 14---------------------------------------
#  Razão Social             | ATA - AEROTÁXI AB...
#  ICAO IATA                | ABJ
#  CNPJ                     | 14.674.451/0001-19
#  Atividades Aéreas        | TÁXI-AÉREO, TRANS...
#  Endereço Sede            |  PÇA. GAGO COUTIN...
#  Telefone                 | (71) 34629600 / (...
#  E-Mail                   | guilherme@abaete....
#  Decisão Operacional      | DECISÃO Nº 36
#  Data Decisão Operacional | 05/03/2020
#  Validade Operacional     | null
# -RECORD 15---------------------------------------
#  Razão Social             | OMNI TÁXI AÉREO S.A.
#  ICAO IATA                | OMI O1
#  CNPJ                     | 03.670.763/0001-38
#  Atividades Aéreas        | AEROFOTOGRAFIA, A...
#  Endereço Sede            | AV. AYRTON SENNA,...
#  Telefone                 | (61) 98335-3444
#  E-Mail                   | lira@plfconsultor...
#  Decisão Operacional      | DECISÃO Nº 100
#  Data Decisão Operacional | 10/07/2019
#  Validade Operacional     | 12/07/2024
# -RECORD 16---------------------------------------
#  Razão Social             | PRIME TÁXI AIR LTDA
#  ICAO IATA                | null
#  CNPJ                     | 23.568.370/0001-25
#  Atividades Aéreas        | TÁXI-AÉREO, TRANS...
#  Endereço Sede            | AL. RIO NEGRO, 58...
#  Telefone                 | (11) 41958307 / (...
#  E-Mail                   | mmatta@primefract...
#  Decisão Operacional      | DECISÃO Nº 237
#  Data Decisão Operacional | 17/12/2020
#  Validade Operacional     | 18/12/2025
# -RECORD 17---------------------------------------
#  Razão Social             | SIDERAL LINHAS AÉ...
#  ICAO IATA                | SID 0S
#  CNPJ                     | 10.919.908/0001-57
#  Atividades Aéreas        | TRANSPORTE AÉREO ...
#  Endereço Sede            | RODOVIA CONTORNO ...
#  Telefone                 | (41) 3116-9000 / ...
#  E-Mail                   | office@siderallin...
#  Decisão Operacional      | DECISÃO Nº 37
#  Data Decisão Operacional | 05/03/2020
#  Validade Operacional     | 06/03/2025
# -RECORD 18---------------------------------------
#  Razão Social             | RIMA - RIO MADEIR...
#  ICAO IATA                | RIM 0R
#  CNPJ                     | 04.778.630/0001-42
#  Atividades Aéreas        | LIGAÇÃO AÉREA SIS...
#  Endereço Sede            | AV. LAURO SODRÉ, ...
#  Telefone                 | (69) 3225-8000
#  E-Mail                   | null
#  Decisão Operacional      | DECISÃO Nº 116
#  Data Decisão Operacional | 26/07/2017
#  Validade Operacional     | 27/07/2022
# -RECORD 19---------------------------------------
#  Razão Social             | RTS - ROTA DO SOL...
#  ICAO IATA                | CKP
#  CNPJ                     | 01.904.715/0001-31
#  Atividades Aéreas        | LIGAÇÃO AÉREA SIS...
#  Endereço Sede            | PRAÇA EDUARDO GOM...
#  Telefone                 | (85) 3272-3555
#  E-Mail                   | quadros@voerotado...
#  Decisão Operacional      | DECISÃO Nº 21
#  Data Decisão Operacional | 13/02/2019
#  Validade Operacional     | 15/02/2024

# %% [markdown]
# ### Normalizar o cabeçalho para snake case

# %%
##CRIANDO DICIONARIO COM OS ACENTOS e o Ç ALEM DE CARACTERES ESPECIAIS (NECESSITA A ADICAO DE MAIS COLOQUEI APENAS O - PARA SERVIR DE EXEMPLO)
accented_characters = {
 'á': 'a', 'à': 'a', 'â': 'a', 'ã': 'a', 'ä': 'a',
    'é': 'e', 'è': 'e', 'ê': 'e', 'ë': 'e',
    'í': 'i', 'ì': 'i', 'î': 'i', 'ï': 'i',
    'ó': 'o', 'ò': 'o', 'ô': 'o', 'õ': 'o', 'ö': 'o',
    'ú': 'u', 'ù': 'u', 'û': 'u', 'ü': 'u',
    'ç': 'c','-':''
    }

##TRANSFORMANDO O DICIONARIO EM SUA VERSAO "UNICODE" PARA PODER USAR O METODO STR.TRANSLATE
translation_table = str.maketrans(accented_characters)
novas_colunas = []
for column in df_aircia.columns:
    novas_colunas.append(column.lower().translate(translation_table).replace(' ','_'))

## USANDO UM FOR PARA TROCAR TODOS OS NOMES ANTIGOS PELOS NOVOS NOMES
## O ZIP JUNTA AS DUAS LISTAS (A LISTA ORIGINAL DE COLUNAS COM A LISTA QUE EU CRIEI COM OS NOVOS NOMES)
## A FUNCAO WITHCOLUMNRENAMED TROCA OS NOME DAS COLUNAS (FUNCIONA COMO SE FOSSE UM SELECT COLUMN AS EXAMPLE)
for nome_antigo,nome_novo in zip(df_aircia.columns,novas_colunas):
    df_aircia = df_aircia.withColumnRenamed(nome_antigo,nome_novo)

# %%
df_aircia.show(vertical=True)
# Out:
# -RECORD 0----------------------------------------
#  razao_social             | ABSA - AEROLINHAS...
#  icao_iata                | LTG M3
#  cnpj                     | 00.074.635/0001-33
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AEROPORTO INTERNA...
#  telefone                 | (11) 5582-8055
#  email                    | gar@tam.com.br
#  decisao_operacional      | DECISÃO Nº 41
#  data_decisao_operacional | 22/04/2015
#  validade_operacional     | 23/04/2025
# -RECORD 1----------------------------------------
#  razao_social             | AEROSUL TÁXI AÉRE...
#  icao_iata                | ASO 2S
#  cnpj                     | 27.315.694/0001-02
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | RODOVIA PR 218, K...
#  telefone                 | (43) 3176-4030
#  email                    | operacoes@aerosul...
#  decisao_operacional      | DECISÃO Nº 282
#  data_decisao_operacional | 10/02/2021
#  validade_operacional     | null
# -RECORD 2----------------------------------------
#  razao_social             | ASTA LINHAS AÉREA...
#  icao_iata                | SUL 0A
#  cnpj                     | 12.703.737/0001-50
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | AV GOVERNADOR JOÃ...
#  telefone                 | (65) 3614-2684 / ...
#  email                    | null
#  decisao_operacional      | DECISÃO Nº 115
#  data_decisao_operacional | 31/07/2019
#  validade_operacional     | 02/08/2024
# -RECORD 3----------------------------------------
#  razao_social             | ATA - AEROTÁXI AB...
#  icao_iata                | ABJ
#  cnpj                     | 14.674.451/0001-19
#  atividades_aereas        | TÁXI-AÉREO, TRANS...
#  endereco_sede            |  PÇA. GAGO COUTIN...
#  telefone                 | (71) 34629600 / (...
#  email                    | guilherme@abaete....
#  decisao_operacional      | DECISÃO Nº 36
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | null
# -RECORD 4----------------------------------------
#  razao_social             | AZUL CONECTA LTDA...
#  icao_iata                | ACN 2F
#  cnpj                     | 04.263.318/0001-16
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AVENIDA EMILIO AN...
#  telefone                 | (11) 45822355/ (1...
#  email                    | null
#  decisao_operacional      | Decisão nº 14, de...
#  data_decisao_operacional | 25/01/2018
#  validade_operacional     | 29/01/2028
# -RECORD 5----------------------------------------
#  razao_social             | AZUL LINHAS AÉREA...
#  icao_iata                | AZU AD
#  cnpj                     | 09.296.295/0001-60
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AV. MARCOS PENTEA...
#  telefone                 |  (55) (11) 4134-9...
#  email                    | vanessa.reis@voea...
#  decisao_operacional      | Decisão nº 178
#  data_decisao_operacional | 20/11/2018
#  validade_operacional     | 21/11/2028
# -RECORD 6----------------------------------------
#  razao_social             | GOL LINHAS AÉREAS...
#  icao_iata                | GLO G3
#  cnpj                     | 07.575.651/0001-59
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | PRAÇA SENADOR SAL...
#  telefone                 | (11) 5098-2990 / ...
#  email                    | rddfonseca@voegol...
#  decisao_operacional      | DECISÃO Nº 156
#  data_decisao_operacional | 05/11/2019
#  validade_operacional     | null
# -RECORD 7----------------------------------------
#  razao_social             | MAP TRANSPORTES A...
#  icao_iata                | PAM 7M
#  cnpj                     | 10.483.635/0001-40
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AVENIDA SANTOS DU...
#  telefone                 | (92) 36521620
#  email                    | contabil@voemap.c...
#  decisao_operacional      | DECISÃO Nº 89
#  data_decisao_operacional | 14/08/2012
#  validade_operacional     | 17/08/2022
# -RECORD 8----------------------------------------
#  razao_social             | MODERN TRANSPORTE...
#  icao_iata                | MWM WD
#  cnpj                     | 03.887.831/0001-15
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AVENIDA PREFEITO ...
#  telefone                 | (21) 2272-9272 / ...
#  email                    | juridico@modern.c...
#  decisao_operacional      | DECISÃO Nº 79
#  data_decisao_operacional | 31/05/2017
#  validade_operacional     | 02/06/2027
# -RECORD 9----------------------------------------
#  razao_social             | PASSAREDO TRANSPO...
#  icao_iata                | PTB 2Z
#  cnpj                     | 00.512.777/0001-35
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | SETOR DE HANGARES...
#  telefone                 | (16) 3514-7127 / ...
#  email                    | juridico@voepass....
#  decisao_operacional      | DECISÃO Nº 105
#  data_decisao_operacional | 09/06/2020
#  validade_operacional     | null
# -RECORD 10---------------------------------------
#  razao_social             | SIDERAL LINHAS AÉ...
#  icao_iata                | SID 0S
#  cnpj                     | 10.919.908/0001-57
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | RODOVIA CONTORNO ...
#  telefone                 | (41) 3116-9000 / ...
#  email                    | office@siderallin...
#  decisao_operacional      | DECISÃO Nº 37
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | 06/03/2025
# -RECORD 11---------------------------------------
#  razao_social             | TAM LINHAS AÉREAS...
#  icao_iata                | TAM JJ
#  cnpj                     | 02.012.862/0001-60
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | RUA ÁTICA , N° 67...
#  telefone                 | (11) 5582-8055 / ...
#  email                    | gar@tam.com.br
#  decisao_operacional      | DECISÃO Nº 366
#  data_decisao_operacional | 07/07/2021
#  validade_operacional     | 09/11/2031
# -RECORD 12---------------------------------------
#  razao_social             | TOTAL LINHAS AÉRE...
#  icao_iata                | TTL L1
#  cnpj                     | 32.068.363/0001-55
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | AV. SENADOR SALGA...
#  telefone                 | (41) 3371-8200 / ...
#  email                    | geraldo.antonio@t...
#  decisao_operacional      | DECISÃO Nº 260
#  data_decisao_operacional | 12/01/2021
#  validade_operacional     | 14/01/2031
# -RECORD 13---------------------------------------
#  razao_social             | AEROSUL TÁXI AÉRE...
#  icao_iata                | ASO 2S
#  cnpj                     | 27.315.694/0001-02
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | RODOVIA PR 218, K...
#  telefone                 | (43) 3176-4030
#  email                    | operacoes@aerosul...
#  decisao_operacional      | DECISÃO Nº 282
#  data_decisao_operacional | 10/02/2021
#  validade_operacional     | null
# -RECORD 14---------------------------------------
#  razao_social             | ATA - AEROTÁXI AB...
#  icao_iata                | ABJ
#  cnpj                     | 14.674.451/0001-19
#  atividades_aereas        | TÁXI-AÉREO, TRANS...
#  endereco_sede            |  PÇA. GAGO COUTIN...
#  telefone                 | (71) 34629600 / (...
#  email                    | guilherme@abaete....
#  decisao_operacional      | DECISÃO Nº 36
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | null
# -RECORD 15---------------------------------------
#  razao_social             | OMNI TÁXI AÉREO S.A.
#  icao_iata                | OMI O1
#  cnpj                     | 03.670.763/0001-38
#  atividades_aereas        | AEROFOTOGRAFIA, A...
#  endereco_sede            | AV. AYRTON SENNA,...
#  telefone                 | (61) 98335-3444
#  email                    | lira@plfconsultor...
#  decisao_operacional      | DECISÃO Nº 100
#  data_decisao_operacional | 10/07/2019
#  validade_operacional     | 12/07/2024
# -RECORD 16---------------------------------------
#  razao_social             | PRIME TÁXI AIR LTDA
#  icao_iata                | null
#  cnpj                     | 23.568.370/0001-25
#  atividades_aereas        | TÁXI-AÉREO, TRANS...
#  endereco_sede            | AL. RIO NEGRO, 58...
#  telefone                 | (11) 41958307 / (...
#  email                    | mmatta@primefract...
#  decisao_operacional      | DECISÃO Nº 237
#  data_decisao_operacional | 17/12/2020
#  validade_operacional     | 18/12/2025
# -RECORD 17---------------------------------------
#  razao_social             | SIDERAL LINHAS AÉ...
#  icao_iata                | SID 0S
#  cnpj                     | 10.919.908/0001-57
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | RODOVIA CONTORNO ...
#  telefone                 | (41) 3116-9000 / ...
#  email                    | office@siderallin...
#  decisao_operacional      | DECISÃO Nº 37
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | 06/03/2025
# -RECORD 18---------------------------------------
#  razao_social             | RIMA - RIO MADEIR...
#  icao_iata                | RIM 0R
#  cnpj                     | 04.778.630/0001-42
#  atividades_aereas        | LIGAÇÃO AÉREA SIS...
#  endereco_sede            | AV. LAURO SODRÉ, ...
#  telefone                 | (69) 3225-8000
#  email                    | null
#  decisao_operacional      | DECISÃO Nº 116
#  data_decisao_operacional | 26/07/2017
#  validade_operacional     | 27/07/2022
# -RECORD 19---------------------------------------
#  razao_social             | RTS - ROTA DO SOL...
#  icao_iata                | CKP
#  cnpj                     | 01.904.715/0001-31
#  atividades_aereas        | LIGAÇÃO AÉREA SIS...
#  endereco_sede            | PRAÇA EDUARDO GOM...
#  telefone                 | (85) 3272-3555
#  email                    | quadros@voerotado...
#  decisao_operacional      | DECISÃO Nº 21
#  data_decisao_operacional | 13/02/2019
#  validade_operacional     | 15/02/2024

# %% [markdown]
# ### Separar a coluna 'ICAO IATA' em duas colunas, seu conteúdo está separado por espaço e pode não conter o código IATA, caso não contenha o código IATA, deixe o valor nulo.

# %%
df_aircia = (
    df_aircia
    .withColumn('icao',F.split(F.col('icao_iata'),' ')[0])
    .withColumn('iata',F.split(F.col('icao_iata'),' ')[1])
    .drop(F.col('icao_iata'))
)

df_aircia.show(vertical=True)
# Out:
# -RECORD 0----------------------------------------
#  razao_social             | ABSA - AEROLINHAS...
#  cnpj                     | 00.074.635/0001-33
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AEROPORTO INTERNA...
#  telefone                 | (11) 5582-8055
#  email                    | gar@tam.com.br
#  decisao_operacional      | DECISÃO Nº 41
#  data_decisao_operacional | 22/04/2015
#  validade_operacional     | 23/04/2025
#  icao                     | LTG
#  iata                     | M3
# -RECORD 1----------------------------------------
#  razao_social             | AEROSUL TÁXI AÉRE...
#  cnpj                     | 27.315.694/0001-02
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | RODOVIA PR 218, K...
#  telefone                 | (43) 3176-4030
#  email                    | operacoes@aerosul...
#  decisao_operacional      | DECISÃO Nº 282
#  data_decisao_operacional | 10/02/2021
#  validade_operacional     | null
#  icao                     | ASO
#  iata                     | 2S
# -RECORD 2----------------------------------------
#  razao_social             | ASTA LINHAS AÉREA...
#  cnpj                     | 12.703.737/0001-50
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | AV GOVERNADOR JOÃ...
#  telefone                 | (65) 3614-2684 / ...
#  email                    | null
#  decisao_operacional      | DECISÃO Nº 115
#  data_decisao_operacional | 31/07/2019
#  validade_operacional     | 02/08/2024
#  icao                     | SUL
#  iata                     | 0A
# -RECORD 3----------------------------------------
#  razao_social             | ATA - AEROTÁXI AB...
#  cnpj                     | 14.674.451/0001-19
#  atividades_aereas        | TÁXI-AÉREO, TRANS...
#  endereco_sede            |  PÇA. GAGO COUTIN...
#  telefone                 | (71) 34629600 / (...
#  email                    | guilherme@abaete....
#  decisao_operacional      | DECISÃO Nº 36
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | null
#  icao                     | ABJ
#  iata                     | null
# -RECORD 4----------------------------------------
#  razao_social             | AZUL CONECTA LTDA...
#  cnpj                     | 04.263.318/0001-16
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AVENIDA EMILIO AN...
#  telefone                 | (11) 45822355/ (1...
#  email                    | null
#  decisao_operacional      | Decisão nº 14, de...
#  data_decisao_operacional | 25/01/2018
#  validade_operacional     | 29/01/2028
#  icao                     | ACN
#  iata                     | 2F
# -RECORD 5----------------------------------------
#  razao_social             | AZUL LINHAS AÉREA...
#  cnpj                     | 09.296.295/0001-60
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AV. MARCOS PENTEA...
#  telefone                 |  (55) (11) 4134-9...
#  email                    | vanessa.reis@voea...
#  decisao_operacional      | Decisão nº 178
#  data_decisao_operacional | 20/11/2018
#  validade_operacional     | 21/11/2028
#  icao                     | AZU
#  iata                     | AD
# -RECORD 6----------------------------------------
#  razao_social             | GOL LINHAS AÉREAS...
#  cnpj                     | 07.575.651/0001-59
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | PRAÇA SENADOR SAL...
#  telefone                 | (11) 5098-2990 / ...
#  email                    | rddfonseca@voegol...
#  decisao_operacional      | DECISÃO Nº 156
#  data_decisao_operacional | 05/11/2019
#  validade_operacional     | null
#  icao                     | GLO
#  iata                     | G3
# -RECORD 7----------------------------------------
#  razao_social             | MAP TRANSPORTES A...
#  cnpj                     | 10.483.635/0001-40
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AVENIDA SANTOS DU...
#  telefone                 | (92) 36521620
#  email                    | contabil@voemap.c...
#  decisao_operacional      | DECISÃO Nº 89
#  data_decisao_operacional | 14/08/2012
#  validade_operacional     | 17/08/2022
#  icao                     | PAM
#  iata                     | 7M
# -RECORD 8----------------------------------------
#  razao_social             | MODERN TRANSPORTE...
#  cnpj                     | 03.887.831/0001-15
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AVENIDA PREFEITO ...
#  telefone                 | (21) 2272-9272 / ...
#  email                    | juridico@modern.c...
#  decisao_operacional      | DECISÃO Nº 79
#  data_decisao_operacional | 31/05/2017
#  validade_operacional     | 02/06/2027
#  icao                     | MWM
#  iata                     | WD
# -RECORD 9----------------------------------------
#  razao_social             | PASSAREDO TRANSPO...
#  cnpj                     | 00.512.777/0001-35
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | SETOR DE HANGARES...
#  telefone                 | (16) 3514-7127 / ...
#  email                    | juridico@voepass....
#  decisao_operacional      | DECISÃO Nº 105
#  data_decisao_operacional | 09/06/2020
#  validade_operacional     | null
#  icao                     | PTB
#  iata                     | 2Z
# -RECORD 10---------------------------------------
#  razao_social             | SIDERAL LINHAS AÉ...
#  cnpj                     | 10.919.908/0001-57
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | RODOVIA CONTORNO ...
#  telefone                 | (41) 3116-9000 / ...
#  email                    | office@siderallin...
#  decisao_operacional      | DECISÃO Nº 37
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | 06/03/2025
#  icao                     | SID
#  iata                     | 0S
# -RECORD 11---------------------------------------
#  razao_social             | TAM LINHAS AÉREAS...
#  cnpj                     | 02.012.862/0001-60
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | RUA ÁTICA , N° 67...
#  telefone                 | (11) 5582-8055 / ...
#  email                    | gar@tam.com.br
#  decisao_operacional      | DECISÃO Nº 366
#  data_decisao_operacional | 07/07/2021
#  validade_operacional     | 09/11/2031
#  icao                     | TAM
#  iata                     | JJ
# -RECORD 12---------------------------------------
#  razao_social             | TOTAL LINHAS AÉRE...
#  cnpj                     | 32.068.363/0001-55
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | AV. SENADOR SALGA...
#  telefone                 | (41) 3371-8200 / ...
#  email                    | geraldo.antonio@t...
#  decisao_operacional      | DECISÃO Nº 260
#  data_decisao_operacional | 12/01/2021
#  validade_operacional     | 14/01/2031
#  icao                     | TTL
#  iata                     | L1
# -RECORD 13---------------------------------------
#  razao_social             | AEROSUL TÁXI AÉRE...
#  cnpj                     | 27.315.694/0001-02
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | RODOVIA PR 218, K...
#  telefone                 | (43) 3176-4030
#  email                    | operacoes@aerosul...
#  decisao_operacional      | DECISÃO Nº 282
#  data_decisao_operacional | 10/02/2021
#  validade_operacional     | null
#  icao                     | ASO
#  iata                     | 2S
# -RECORD 14---------------------------------------
#  razao_social             | ATA - AEROTÁXI AB...
#  cnpj                     | 14.674.451/0001-19
#  atividades_aereas        | TÁXI-AÉREO, TRANS...
#  endereco_sede            |  PÇA. GAGO COUTIN...
#  telefone                 | (71) 34629600 / (...
#  email                    | guilherme@abaete....
#  decisao_operacional      | DECISÃO Nº 36
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | null
#  icao                     | ABJ
#  iata                     | null
# -RECORD 15---------------------------------------
#  razao_social             | OMNI TÁXI AÉREO S.A.
#  cnpj                     | 03.670.763/0001-38
#  atividades_aereas        | AEROFOTOGRAFIA, A...
#  endereco_sede            | AV. AYRTON SENNA,...
#  telefone                 | (61) 98335-3444
#  email                    | lira@plfconsultor...
#  decisao_operacional      | DECISÃO Nº 100
#  data_decisao_operacional | 10/07/2019
#  validade_operacional     | 12/07/2024
#  icao                     | OMI
#  iata                     | O1
# -RECORD 16---------------------------------------
#  razao_social             | PRIME TÁXI AIR LTDA
#  cnpj                     | 23.568.370/0001-25
#  atividades_aereas        | TÁXI-AÉREO, TRANS...
#  endereco_sede            | AL. RIO NEGRO, 58...
#  telefone                 | (11) 41958307 / (...
#  email                    | mmatta@primefract...
#  decisao_operacional      | DECISÃO Nº 237
#  data_decisao_operacional | 17/12/2020
#  validade_operacional     | 18/12/2025
#  icao                     | null
#  iata                     | null
# -RECORD 17---------------------------------------
#  razao_social             | SIDERAL LINHAS AÉ...
#  cnpj                     | 10.919.908/0001-57
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | RODOVIA CONTORNO ...
#  telefone                 | (41) 3116-9000 / ...
#  email                    | office@siderallin...
#  decisao_operacional      | DECISÃO Nº 37
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | 06/03/2025
#  icao                     | SID
#  iata                     | 0S
# -RECORD 18---------------------------------------
#  razao_social             | RIMA - RIO MADEIR...
#  cnpj                     | 04.778.630/0001-42
#  atividades_aereas        | LIGAÇÃO AÉREA SIS...
#  endereco_sede            | AV. LAURO SODRÉ, ...
#  telefone                 | (69) 3225-8000
#  email                    | null
#  decisao_operacional      | DECISÃO Nº 116
#  data_decisao_operacional | 26/07/2017
#  validade_operacional     | 27/07/2022
#  icao                     | RIM
#  iata                     | 0R
# -RECORD 19---------------------------------------
#  razao_social             | RTS - ROTA DO SOL...
#  cnpj                     | 01.904.715/0001-31
#  atividades_aereas        | LIGAÇÃO AÉREA SIS...
#  endereco_sede            | PRAÇA EDUARDO GOM...
#  telefone                 | (85) 3272-3555
#  email                    | quadros@voerotado...
#  decisao_operacional      | DECISÃO Nº 21
#  data_decisao_operacional | 13/02/2019
#  validade_operacional     | 15/02/2024
#  icao                     | CKP
#  iata                     | null

# %% [markdown]
# ### Salvar estes dados

# %%
df_aircia.coalesce(1).write.mode('overwrite').parquet('silver/AIR_CIA/aircia.parquet')

# %% [markdown]
# ## Carrega os dados VRA

# %%
##PARA EVITAR O USO EXCESSIVO DE MEMORIA NO IFFERSCHEMA DO SPARK, ESTOU PEGANDO UM UNICO ARQUIVO E USANDO O SCHEMA DELE PARA TODOS
df_vra = spark.read.json('bronze/VRA/VRA_20213.json')
schema = df_vra.schema

## DESALOCO A VARIAVEL DF_VRA COMO BOA PRATICA POIS VOU REUSALO
del df_vra
df_vra = spark.read.json('bronze/VRA/',schema=schema)
df_vra.show(vertical=True)
# Out:
# -RECORD 0-----------------------------------
#  ChegadaPrevista      | 2021-01-19 14:45:00
#  ChegadaReal          | 2021-01-19 19:22:00
#  CódigoAutorização    | 7
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBEG
#  ICAOAeródromoOrigem  | SBBE
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 9702
#  PartidaPrevista      | 2021-01-19 12:35:00
#  PartidaReal          | 2021-01-19 17:17:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 1-----------------------------------
#  ChegadaPrevista      | 2021-01-26 12:05:00
#  ChegadaReal          | 2021-01-26 12:04:00
#  CódigoAutorização    | 7
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBPA
#  ICAOAeródromoOrigem  | SBGL
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 9701
#  PartidaPrevista      | 2021-01-26 10:00:00
#  PartidaReal          | 2021-01-26 09:55:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 2-----------------------------------
#  ChegadaPrevista      | 2021-01-18 23:20:00
#  ChegadaReal          | 2021-01-19 00:50:00
#  CódigoAutorização    | 7
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBBE
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 9701
#  PartidaPrevista      | 2021-01-18 21:15:00
#  PartidaReal          | 2021-01-18 22:35:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 3-----------------------------------
#  ChegadaPrevista      | 2021-01-15 00:45:00
#  ChegadaReal          | 2021-01-15 00:39:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBEG
#  ICAOAeródromoOrigem  | SBGL
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 9700
#  PartidaPrevista      | 2021-01-14 20:30:00
#  PartidaReal          | 2021-01-14 20:27:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 4-----------------------------------
#  ChegadaPrevista      | 2021-01-24 15:10:00
#  ChegadaReal          | 2021-01-24 23:21:00
#  CódigoAutorização    | 7
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBEG
#  ICAOAeródromoOrigem  | SBKP
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 9700
#  PartidaPrevista      | 2021-01-24 11:30:00
#  PartidaReal          | 2021-01-24 19:35:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 5-----------------------------------
#  ChegadaPrevista      | 2021-01-15 17:55:00
#  ChegadaReal          | 2021-01-15 18:00:00
#  CódigoAutorização    | 2
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBKP
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 9203
#  PartidaPrevista      | 2021-01-15 14:00:00
#  PartidaReal          | 2021-01-15 14:05:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 6-----------------------------------
#  ChegadaPrevista      | 2021-01-30 15:35:00
#  ChegadaReal          | 2021-01-30 15:16:00
#  CódigoAutorização    | 2
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBKP
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 9203
#  PartidaPrevista      | 2021-01-30 11:40:00
#  PartidaReal          | 2021-01-30 11:25:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 7-----------------------------------
#  ChegadaPrevista      | 2021-01-23 19:10:00
#  ChegadaReal          | 2021-01-23 19:31:00
#  CódigoAutorização    | 2
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBBR
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 9203
#  PartidaPrevista      | 2021-01-23 16:10:00
#  PartidaReal          | 2021-01-23 16:36:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 8-----------------------------------
#  ChegadaPrevista      | 2021-01-14 14:40:00
#  ChegadaReal          | 2021-01-14 14:50:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBRF
#  ICAOAeródromoOrigem  | SBKP
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5806
#  PartidaPrevista      | 2021-01-14 11:30:00
#  PartidaReal          | 2021-01-14 11:42:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 9-----------------------------------
#  ChegadaPrevista      | 2021-01-12 14:10:00
#  ChegadaReal          | 2021-01-12 14:48:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBRF
#  ICAOAeródromoOrigem  | SBKP
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5806
#  PartidaPrevista      | 2021-01-12 11:00:00
#  PartidaReal          | 2021-01-12 11:21:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 10----------------------------------
#  ChegadaPrevista      | 2021-01-07 14:10:00
#  ChegadaReal          | 2021-01-07 14:18:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBRF
#  ICAOAeródromoOrigem  | SBKP
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5806
#  PartidaPrevista      | 2021-01-07 11:00:00
#  PartidaReal          | 2021-01-07 11:00:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 11----------------------------------
#  ChegadaPrevista      | 2021-01-05 14:10:00
#  ChegadaReal          | 2021-01-05 14:51:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBRF
#  ICAOAeródromoOrigem  | SBKP
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5806
#  PartidaPrevista      | 2021-01-05 11:00:00
#  PartidaReal          | 2021-01-05 11:35:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 12----------------------------------
#  ChegadaPrevista      | 2021-01-28 12:45:00
#  ChegadaReal          | 2021-01-28 12:52:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBKP
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5803
#  PartidaPrevista      | 2021-01-28 08:50:00
#  PartidaReal          | 2021-01-28 08:56:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 13----------------------------------
#  ChegadaPrevista      | 2021-01-23 10:15:00
#  ChegadaReal          | 2021-01-23 10:19:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBKP
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5803
#  PartidaPrevista      | 2021-01-23 06:20:00
#  PartidaReal          | 2021-01-23 06:26:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 14----------------------------------
#  ChegadaPrevista      | 2021-01-19 09:45:00
#  ChegadaReal          | 2021-01-19 09:30:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBKP
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5803
#  PartidaPrevista      | 2021-01-19 02:50:00
#  PartidaReal          | 2021-01-19 05:41:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 15----------------------------------
#  ChegadaPrevista      | 2021-01-14 09:45:00
#  ChegadaReal          | 2021-01-14 09:32:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBKP
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5803
#  PartidaPrevista      | 2021-01-14 05:50:00
#  PartidaReal          | 2021-01-14 05:46:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 16----------------------------------
#  ChegadaPrevista      | 2021-01-05 08:05:00
#  ChegadaReal          | 2021-01-05 07:45:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBKP
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5803
#  PartidaPrevista      | 2021-01-05 04:10:00
#  PartidaReal          | 2021-01-05 03:57:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 17----------------------------------
#  ChegadaPrevista      | 2021-01-30 11:50:00
#  ChegadaReal          | 2021-01-30 11:53:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBBR
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5803
#  PartidaPrevista      | 2021-01-30 08:50:00
#  PartidaReal          | 2021-01-30 08:41:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 18----------------------------------
#  ChegadaPrevista      | 2021-01-26 11:50:00
#  ChegadaReal          | 2021-01-26 11:40:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBBR
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5803
#  PartidaPrevista      | 2021-01-26 08:50:00
#  PartidaReal          | 2021-01-26 08:42:00
#  SituaçãoVoo          | REALIZADO
# -RECORD 19----------------------------------
#  ChegadaPrevista      | 2021-01-21 06:50:00
#  ChegadaReal          | 2021-01-21 06:50:00
#  CódigoAutorização    | 0
#  CódigoJustificativa  | N/A
#  CódigoTipoLinha      | C
#  ICAOAeródromoDestino | SBBR
#  ICAOAeródromoOrigem  | SBEG
#  ICAOEmpresaAérea     | MWM
#  NúmeroVoo            | 5803
#  PartidaPrevista      | 2021-01-21 03:50:00
#  PartidaReal          | 2021-01-21 03:52:00
#  SituaçãoVoo          | REALIZADO
# only showing top 20 rows

# %% [markdown]
# ### Normalizar o cabeçalho para snake case

# %%
import re

def pascal_to_snake(pascal_case_string):
    # Use regular expression to insert underscores before uppercase letters
    snake_case_string = re.sub(r'(?<=.)([A-Z])', r'_\1', pascal_case_string)
    # Convert the string to lowercase
    snake_case_string = snake_case_string.lower()
    return snake_case_string

# Example usage:
pascal_string = "PascalCaseString"
snake_string = pascal_to_snake(pascal_string)
print(snake_string)  # Output: "pascal_case_string"
# Out:
# pascal_case_string

# %%
 ##TRANSFORMANDO O DICIONARIO EM SUA VERSAO "UNICODE" PARA PODER USAR O METODO STR.TRANSLATE O ACCENTD JÁ FOI DEFINIDO ANTERIORMENTE
novas_colunas = []
for column in df_vra.columns:
#     novas_colunas.append(pascal_to_snake(column))
    novas_colunas.append(pascal_to_snake(column.replace('ICAO','Icao').translate(translation_table)))

## USANDO UM FOR PARA TROCAR TODOS OS NOMES ANTIGOS PELOS NOVOS NOMES
## O ZIP JUNTA AS DUAS LISTAS (A LISTA ORIGINAL DE COLUNAS COM A LISTA QUE EU CRIEI COM OS NOVOS NOMES)
## A FUNCAO WITHCOLUMNRENAMED TROCA OS NOME DAS COLUNAS (FUNCIONA COMO SE FOSSE UM SELECT COLUMN AS EXAMPLE)
for nome_antigo,nome_novo in zip(df_vra.columns,novas_colunas):
    df_vra = df_vra.withColumnRenamed(nome_antigo,nome_novo)

# %%
df_vra.show(vertical=True)
# Out:
# -RECORD 0-------------------------------------
#  chegada_prevista       | 2021-01-19 14:45:00
#  chegada_real           | 2021-01-19 19:22:00
#  codigo_autorizacao     | 7
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBEG
#  icao_aerodromo_origem  | SBBE
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9702
#  partida_prevista       | 2021-01-19 12:35:00
#  partida_real           | 2021-01-19 17:17:00
#  situacao_voo           | REALIZADO
# -RECORD 1-------------------------------------
#  chegada_prevista       | 2021-01-26 12:05:00
#  chegada_real           | 2021-01-26 12:04:00
#  codigo_autorizacao     | 7
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBPA
#  icao_aerodromo_origem  | SBGL
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9701
#  partida_prevista       | 2021-01-26 10:00:00
#  partida_real           | 2021-01-26 09:55:00
#  situacao_voo           | REALIZADO
# -RECORD 2-------------------------------------
#  chegada_prevista       | 2021-01-18 23:20:00
#  chegada_real           | 2021-01-19 00:50:00
#  codigo_autorizacao     | 7
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBBE
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9701
#  partida_prevista       | 2021-01-18 21:15:00
#  partida_real           | 2021-01-18 22:35:00
#  situacao_voo           | REALIZADO
# -RECORD 3-------------------------------------
#  chegada_prevista       | 2021-01-15 00:45:00
#  chegada_real           | 2021-01-15 00:39:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBEG
#  icao_aerodromo_origem  | SBGL
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9700
#  partida_prevista       | 2021-01-14 20:30:00
#  partida_real           | 2021-01-14 20:27:00
#  situacao_voo           | REALIZADO
# -RECORD 4-------------------------------------
#  chegada_prevista       | 2021-01-24 15:10:00
#  chegada_real           | 2021-01-24 23:21:00
#  codigo_autorizacao     | 7
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBEG
#  icao_aerodromo_origem  | SBKP
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9700
#  partida_prevista       | 2021-01-24 11:30:00
#  partida_real           | 2021-01-24 19:35:00
#  situacao_voo           | REALIZADO
# -RECORD 5-------------------------------------
#  chegada_prevista       | 2021-01-15 17:55:00
#  chegada_real           | 2021-01-15 18:00:00
#  codigo_autorizacao     | 2
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9203
#  partida_prevista       | 2021-01-15 14:00:00
#  partida_real           | 2021-01-15 14:05:00
#  situacao_voo           | REALIZADO
# -RECORD 6-------------------------------------
#  chegada_prevista       | 2021-01-30 15:35:00
#  chegada_real           | 2021-01-30 15:16:00
#  codigo_autorizacao     | 2
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9203
#  partida_prevista       | 2021-01-30 11:40:00
#  partida_real           | 2021-01-30 11:25:00
#  situacao_voo           | REALIZADO
# -RECORD 7-------------------------------------
#  chegada_prevista       | 2021-01-23 19:10:00
#  chegada_real           | 2021-01-23 19:31:00
#  codigo_autorizacao     | 2
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBBR
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9203
#  partida_prevista       | 2021-01-23 16:10:00
#  partida_real           | 2021-01-23 16:36:00
#  situacao_voo           | REALIZADO
# -RECORD 8-------------------------------------
#  chegada_prevista       | 2021-01-14 14:40:00
#  chegada_real           | 2021-01-14 14:50:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBRF
#  icao_aerodromo_origem  | SBKP
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5806
#  partida_prevista       | 2021-01-14 11:30:00
#  partida_real           | 2021-01-14 11:42:00
#  situacao_voo           | REALIZADO
# -RECORD 9-------------------------------------
#  chegada_prevista       | 2021-01-12 14:10:00
#  chegada_real           | 2021-01-12 14:48:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBRF
#  icao_aerodromo_origem  | SBKP
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5806
#  partida_prevista       | 2021-01-12 11:00:00
#  partida_real           | 2021-01-12 11:21:00
#  situacao_voo           | REALIZADO
# -RECORD 10------------------------------------
#  chegada_prevista       | 2021-01-07 14:10:00
#  chegada_real           | 2021-01-07 14:18:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBRF
#  icao_aerodromo_origem  | SBKP
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5806
#  partida_prevista       | 2021-01-07 11:00:00
#  partida_real           | 2021-01-07 11:00:00
#  situacao_voo           | REALIZADO
# -RECORD 11------------------------------------
#  chegada_prevista       | 2021-01-05 14:10:00
#  chegada_real           | 2021-01-05 14:51:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBRF
#  icao_aerodromo_origem  | SBKP
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5806
#  partida_prevista       | 2021-01-05 11:00:00
#  partida_real           | 2021-01-05 11:35:00
#  situacao_voo           | REALIZADO
# -RECORD 12------------------------------------
#  chegada_prevista       | 2021-01-28 12:45:00
#  chegada_real           | 2021-01-28 12:52:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-28 08:50:00
#  partida_real           | 2021-01-28 08:56:00
#  situacao_voo           | REALIZADO
# -RECORD 13------------------------------------
#  chegada_prevista       | 2021-01-23 10:15:00
#  chegada_real           | 2021-01-23 10:19:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-23 06:20:00
#  partida_real           | 2021-01-23 06:26:00
#  situacao_voo           | REALIZADO
# -RECORD 14------------------------------------
#  chegada_prevista       | 2021-01-19 09:45:00
#  chegada_real           | 2021-01-19 09:30:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-19 02:50:00
#  partida_real           | 2021-01-19 05:41:00
#  situacao_voo           | REALIZADO
# -RECORD 15------------------------------------
#  chegada_prevista       | 2021-01-14 09:45:00
#  chegada_real           | 2021-01-14 09:32:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-14 05:50:00
#  partida_real           | 2021-01-14 05:46:00
#  situacao_voo           | REALIZADO
# -RECORD 16------------------------------------
#  chegada_prevista       | 2021-01-05 08:05:00
#  chegada_real           | 2021-01-05 07:45:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-05 04:10:00
#  partida_real           | 2021-01-05 03:57:00
#  situacao_voo           | REALIZADO
# -RECORD 17------------------------------------
#  chegada_prevista       | 2021-01-30 11:50:00
#  chegada_real           | 2021-01-30 11:53:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBBR
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-30 08:50:00
#  partida_real           | 2021-01-30 08:41:00
#  situacao_voo           | REALIZADO
# -RECORD 18------------------------------------
#  chegada_prevista       | 2021-01-26 11:50:00
#  chegada_real           | 2021-01-26 11:40:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBBR
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-26 08:50:00
#  partida_real           | 2021-01-26 08:42:00
#  situacao_voo           | REALIZADO
# -RECORD 19------------------------------------
#  chegada_prevista       | 2021-01-21 06:50:00
#  chegada_real           | 2021-01-21 06:50:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBBR
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-21 03:50:00
#  partida_real           | 2021-01-21 03:52:00
#  situacao_voo           | REALIZADO
# only showing top 20 rows

# %% [markdown]
# ### Salva os dados

# %%
df_vra.coalesce(1).write.mode('overwrite').parquet('silver/VRA/vra.parquet')

# %% [markdown]
# ## Carrega os dados aerodromos

# %%
## TRANSFORMANDO DOIS SELECTS DISTINCT EM LISTA E JUNTANDO ELES EM UMA LISTA SÓ, LOGO EM SEGUIDA TRANSFORMO ELES EM UM CONJUNTO USNADO O SET() PARA REALZIAR UMA DEDUPLICAÇÂO ENTRE AS LISTAS DEPOIS TRANSFORNO O CONJUNTO NOVAMENTE EM UMA LISTA COM O LIST()
var_icao = list(
    set(
        [i['icao_aerodromo_destino'] for i in df_vra.select('icao_aerodromo_destino').distinct().collect()]
        +
        [i['icao_aerodromo_origem'] for i in df_vra.select('icao_aerodromo_origem').distinct().collect()]
    )
)

# %%
import requests

def get_airport_info(icao):
    url = "https://airport-info.p.rapidapi.com/airport"

    querystring = {"icao":icao}

    headers = {
        "X-RapidAPI-Key": "55207401d8mshd8f1d164058cbebp132c1ajsne2a24955c36e",
        "X-RapidAPI-Host": "airport-info.p.rapidapi.com"
    }

    response = requests.get(url, headers=headers, params=querystring)

    return(response.json())

# %%
airport_info = [get_airport_info(icao) for icao in var_icao]

# %%
###EXCLUDING ERRORS FROM API
airport_info = [i for i in airport_info if len(i)>1]

# %%
pd.DataFrame(airport_info).to_parquet('silver/aerodromos/aerodromos.parquet')

# %% [markdown]
# ## Criação das views

# %%
### LEITURA DAS TABELAS
df_vra = spark.read.parquet('silver/VRA/vra.parquet')

df_aircia = spark.read.parquet('silver/AIR_CIA/aircia.parquet')

df_aerodromos = spark.read.parquet('silver/aerodromos/aerodromos.parquet')

# %% [markdown]
# 1) Para cada companhia aérea trazer a rota mais utilizada com as seguintes informações:
# - Razão social da companhia aérea - air cia
# - Nome Aeroporto de Origem - aerodromos
# - ICAO do aeroporto de origem - vra
# - Estado/UF do aeroporto de origem - aerodromos
# - Nome do Aeroporto de Destino - aerodromos
# - ICAO do Aeroporto de destino - vra
# - Estado/UF do aeroporto de destino - aerodromos

# %%
# CRIA AS VIEWS TEMPORÁRIAS

df_aircia.createTempView('AIR_CIA')
df_vra.createTempView('VRA')
df_aerodromos.createTempView('aerodromo')
# Out:
# True

# %%
df = spark.sql('''
    SELECT 
            RANKED_BASE.qtd_voos, 
            RANKED_BASE.razao_social,
            RANKED_BASE.icao_aerodromo_destino, 
            RANKED_BASE.icao_aerodromo_origem,
            AEROPORTO_ORIGEM.name as name_aeroporto_origem, 
            AEROPORTO_ORIGEM.state as state_aeroporto_origem, 
            AEROPORTO_DESTINO.name as name_aeroporto_destino, 
            AEROPORTO_DESTINO.state as state_aeroporto_destino
        FROM (
        SELECT 
        RANK() over(PARTITION BY BASE.razao_social order by qtd_voos DESC) as rank, *
        FROM (
            SELECT
                COUNT(*) AS qtd_voos,
                A.razao_social,
                V.icao_aerodromo_destino,
                V.icao_aerodromo_origem
            FROM AIR_CIA A
            INNER JOIN VRA V
            ON A.icao = V.icao_empresa_aerea
            GROUP BY
                A.razao_social,
                V.icao_empresa_aerea,
                V.icao_aerodromo_destino,
                V.icao_aerodromo_origem
            ORDER BY 1 DESC
        ) BASE
    )RANKED_BASE
   LEFT JOIN aerodromo AEROPORTO_DESTINO ON AEROPORTO_DESTINO.icao = RANKED_BASE.icao_aerodromo_destino
LEFT JOIN aerodromo AEROPORTO_ORIGEM ON AEROPORTO_ORIGEM.icao = RANKED_BASE.icao_aerodromo_origem
   where rank = 1
    
''').show(vertical=True, truncate=100)
# Out:
# -RECORD 0------------------------------------------------------------------------------------------
#  qtd_voos                | 377
#  razao_social            | ABSA - AEROLINHAS BRASILEIRAS S.A.
#  icao_aerodromo_destino  | KMIA
#  icao_aerodromo_origem   | SEQM
#  name_aeroporto_origem   | Mariscal Sucre International Airport
#  state_aeroporto_origem  | Pichincha
#  name_aeroporto_destino  | Miami International Airport
#  state_aeroporto_destino | Florida
# -RECORD 1------------------------------------------------------------------------------------------
#  qtd_voos                | 52
#  razao_social            | AEROSUL TÁXI AÉREO LTDA (EX.: AUSTEN TÁXI AÉREO LTDA)
#  icao_aerodromo_destino  | SBCD
#  icao_aerodromo_origem   | SBFL
#  name_aeroporto_origem   | Hercílio Luz International Airport
#  state_aeroporto_origem  | Santa Catarina
#  name_aeroporto_destino  | Caçador Airport
#  state_aeroporto_destino | Santa Catarina
# -RECORD 2------------------------------------------------------------------------------------------
#  qtd_voos                | 61
#  razao_social            | ASTA LINHAS AÉREAS LTDA ( EX - AMÉRICA DO SUL LINHAS AÉREAS LTDA.)
#  icao_aerodromo_destino  | SWJN
#  icao_aerodromo_origem   | SBCY
#  name_aeroporto_origem   | Marechal Rondon International Airport
#  state_aeroporto_origem  | Mato Grosso
#  name_aeroporto_destino  | Juína Airport
#  state_aeroporto_destino | State of Mato Grosso
# -RECORD 3------------------------------------------------------------------------------------------
#  qtd_voos                | 34
#  razao_social            | AZUL CONECTA LTDA. (EX TWO TAXI AEREO LTDA)
#  icao_aerodromo_destino  | SBEG
#  icao_aerodromo_origem   | SWKO
#  name_aeroporto_origem   | Coari Airport
#  state_aeroporto_origem  | State of Amazonas
#  name_aeroporto_destino  | Eduardo Gomes International Airport
#  state_aeroporto_destino | Amazonas
# -RECORD 4------------------------------------------------------------------------------------------
#  qtd_voos                | 2540
#  razao_social            | AZUL LINHAS AÉREAS BRASILEIRAS S/A
#  icao_aerodromo_destino  | SBRJ
#  icao_aerodromo_origem   | SBKP
#  name_aeroporto_origem   | Viracopos/Campinas International Airport
#  state_aeroporto_origem  | São Paulo
#  name_aeroporto_destino  | Santos Dumont Airport
#  state_aeroporto_destino | Rio de Janeiro
# -RECORD 5------------------------------------------------------------------------------------------
#  qtd_voos                | 2514
#  razao_social            | GOL LINHAS AÉREAS S.A. (EX- VRG LINHAS AÉREAS S.A.)
#  icao_aerodromo_destino  | SBSP
#  icao_aerodromo_origem   | SBRJ
#  name_aeroporto_origem   | Santos Dumont Airport
#  state_aeroporto_origem  | Rio de Janeiro
#  name_aeroporto_destino  | São Paulo–Congonhas Airport
#  state_aeroporto_destino | São Paulo
# -RECORD 6------------------------------------------------------------------------------------------
#  qtd_voos                | 480
#  razao_social            | MAP TRANSPORTES AÉREOS LTDA.
#  icao_aerodromo_destino  | SBEG
#  icao_aerodromo_origem   | SBUY
#  name_aeroporto_origem   | null
#  state_aeroporto_origem  | null
#  name_aeroporto_destino  | Eduardo Gomes International Airport
#  state_aeroporto_destino | Amazonas
# -RECORD 7------------------------------------------------------------------------------------------
#  qtd_voos                | 480
#  razao_social            | MAP TRANSPORTES AÉREOS LTDA.
#  icao_aerodromo_destino  | SBUY
#  icao_aerodromo_origem   | SBEG
#  name_aeroporto_origem   | Eduardo Gomes International Airport
#  state_aeroporto_origem  | Amazonas
#  name_aeroporto_destino  | null
#  state_aeroporto_destino | null
# -RECORD 8------------------------------------------------------------------------------------------
#  qtd_voos                | 162
#  razao_social            | MODERN TRANSPORTE AEREO DE CARGA S.A
#  icao_aerodromo_destino  | SBBR
#  icao_aerodromo_origem   | SBKP
#  name_aeroporto_origem   | Viracopos/Campinas International Airport
#  state_aeroporto_origem  | São Paulo
#  name_aeroporto_destino  | Brasília International Airport (Presidente J. Kubitschek Int'l Airport)
#  state_aeroporto_destino | Distrito Federal
# -RECORD 9------------------------------------------------------------------------------------------
#  qtd_voos                | 15
#  razao_social            | OMNI TÁXI AÉREO S.A.
#  icao_aerodromo_destino  | SBGL
#  icao_aerodromo_origem   | SBAR
#  name_aeroporto_origem   | Santa Maria Airport
#  state_aeroporto_origem  | California
#  name_aeroporto_destino  | Rio de Janeiro–Galeão International Airport
#  state_aeroporto_destino | Rio de Janeiro
# -RECORD 10-----------------------------------------------------------------------------------------
#  qtd_voos                | 15
#  razao_social            | OMNI TÁXI AÉREO S.A.
#  icao_aerodromo_destino  | SBAR
#  icao_aerodromo_origem   | SBGL
#  name_aeroporto_origem   | Rio de Janeiro–Galeão International Airport
#  state_aeroporto_origem  | Rio de Janeiro
#  name_aeroporto_destino  | Santa Maria Airport
#  state_aeroporto_destino | California
# -RECORD 11-----------------------------------------------------------------------------------------
#  qtd_voos                | 724
#  razao_social            | PASSAREDO TRANSPORTES AÉREOS S.A.
#  icao_aerodromo_destino  | SBSV
#  icao_aerodromo_origem   | SBPS
#  name_aeroporto_origem   | Porto Seguro Airport
#  state_aeroporto_origem  | Bahia
#  name_aeroporto_destino  | Deputado Luís Eduardo Magalhães International Airport
#  state_aeroporto_destino | Bahia
# -RECORD 12-----------------------------------------------------------------------------------------
#  qtd_voos                | 1504
#  razao_social            | SIDERAL LINHAS AÉREAS LTDA.
#  icao_aerodromo_destino  | SBRF
#  icao_aerodromo_origem   | SBGR
#  name_aeroporto_origem   | São Paulo–Guarulhos International Airport
#  state_aeroporto_origem  | São Paulo
#  name_aeroporto_destino  | Recife/Guararapes–Gilberto Freyre International Airport
#  state_aeroporto_destino | Pernambuco
# -RECORD 13-----------------------------------------------------------------------------------------
#  qtd_voos                | 2744
#  razao_social            | TAM LINHAS AÉREAS S.A.
#  icao_aerodromo_destino  | SBRJ
#  icao_aerodromo_origem   | SBSP
#  name_aeroporto_origem   | São Paulo–Congonhas Airport
#  state_aeroporto_origem  | São Paulo
#  name_aeroporto_destino  | Santos Dumont Airport
#  state_aeroporto_destino | Rio de Janeiro
# -RECORD 14-----------------------------------------------------------------------------------------
#  qtd_voos                | 231
#  razao_social            | TOTAL LINHAS AÉREAS S.A.
#  icao_aerodromo_destino  | SBGR
#  icao_aerodromo_origem   | SBCT
#  name_aeroporto_origem   | Afonso Pena International Airport
#  state_aeroporto_origem  | Paraná
#  name_aeroporto_destino  | São Paulo–Guarulhos International Airport
#  state_aeroporto_destino | São Paulo
# -RECORD 15-----------------------------------------------------------------------------------------
#  qtd_voos                | 231
#  razao_social            | TOTAL LINHAS AÉREAS S.A.
#  icao_aerodromo_destino  | SBCT
#  icao_aerodromo_origem   | SBFL
#  name_aeroporto_origem   | Hercílio Luz International Airport
#  state_aeroporto_origem  | Santa Catarina
#  name_aeroporto_destino  | Afonso Pena International Airport
#  state_aeroporto_destino | Paraná

# %%
spark.sql('''
WITH base_crua as (
    SELECT
        COUNT(*) AS qtd_voos,
        A.razao_social,
        V.icao_aerodromo_destino,
        V.icao_aerodromo_origem
    FROM AIR_CIA A
    INNER JOIN VRA V
    ON A.icao = V.icao_empresa_aerea
    GROUP BY
        A.razao_social,
        V.icao_empresa_aerea,
        V.icao_aerodromo_destino,
        V.icao_aerodromo_origem
),
ranked_base as (
    SELECT 
        RANK() over(PARTITION BY razao_social order by qtd_voos DESC) as rank, *
    FROM base_crua
),


select * from base_crua
''')
# Out:
# DataFrame[qtd_voos: bigint, razao_social: string, icao_aerodromo_destino: string, icao_aerodromo_origem: string]

# %% [markdown]
# 2) Para cada aeroporto trazer a companhia aérea com maior atuação no ano com as seguintes informações:
# - Nome do Aeroporto - aerodromos
# - ICAO do Aeroporto - aerodromos
# - Razão social da Companhia Aérea - air cia
# - Quantidade de Rotas à partir daquele aeroporto -
# - Quantidade de Rotas com destino àquele aeroporto -
# - Quantidade total de pousos e decolagens naquele aeroporto -

# %%
df_aircia.show(vertical=True)
# Out:
# -RECORD 0----------------------------------------
#  razao_social             | ABSA - AEROLINHAS...
#  cnpj                     | 00.074.635/0001-33
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AEROPORTO INTERNA...
#  telefone                 | (11) 5582-8055
#  email                    | gar@tam.com.br
#  decisao_operacional      | DECISÃO Nº 41
#  data_decisao_operacional | 22/04/2015
#  validade_operacional     | 23/04/2025
#  icao                     | LTG
#  iata                     | M3
# -RECORD 1----------------------------------------
#  razao_social             | AEROSUL TÁXI AÉRE...
#  cnpj                     | 27.315.694/0001-02
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | RODOVIA PR 218, K...
#  telefone                 | (43) 3176-4030
#  email                    | operacoes@aerosul...
#  decisao_operacional      | DECISÃO Nº 282
#  data_decisao_operacional | 10/02/2021
#  validade_operacional     | null
#  icao                     | ASO
#  iata                     | 2S
# -RECORD 2----------------------------------------
#  razao_social             | ASTA LINHAS AÉREA...
#  cnpj                     | 12.703.737/0001-50
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | AV GOVERNADOR JOÃ...
#  telefone                 | (65) 3614-2684 / ...
#  email                    | null
#  decisao_operacional      | DECISÃO Nº 115
#  data_decisao_operacional | 31/07/2019
#  validade_operacional     | 02/08/2024
#  icao                     | SUL
#  iata                     | 0A
# -RECORD 3----------------------------------------
#  razao_social             | ATA - AEROTÁXI AB...
#  cnpj                     | 14.674.451/0001-19
#  atividades_aereas        | TÁXI-AÉREO, TRANS...
#  endereco_sede            |  PÇA. GAGO COUTIN...
#  telefone                 | (71) 34629600 / (...
#  email                    | guilherme@abaete....
#  decisao_operacional      | DECISÃO Nº 36
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | null
#  icao                     | ABJ
#  iata                     | null
# -RECORD 4----------------------------------------
#  razao_social             | AZUL CONECTA LTDA...
#  cnpj                     | 04.263.318/0001-16
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AVENIDA EMILIO AN...
#  telefone                 | (11) 45822355/ (1...
#  email                    | null
#  decisao_operacional      | Decisão nº 14, de...
#  data_decisao_operacional | 25/01/2018
#  validade_operacional     | 29/01/2028
#  icao                     | ACN
#  iata                     | 2F
# -RECORD 5----------------------------------------
#  razao_social             | AZUL LINHAS AÉREA...
#  cnpj                     | 09.296.295/0001-60
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AV. MARCOS PENTEA...
#  telefone                 |  (55) (11) 4134-9...
#  email                    | vanessa.reis@voea...
#  decisao_operacional      | Decisão nº 178
#  data_decisao_operacional | 20/11/2018
#  validade_operacional     | 21/11/2028
#  icao                     | AZU
#  iata                     | AD
# -RECORD 6----------------------------------------
#  razao_social             | GOL LINHAS AÉREAS...
#  cnpj                     | 07.575.651/0001-59
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | PRAÇA SENADOR SAL...
#  telefone                 | (11) 5098-2990 / ...
#  email                    | rddfonseca@voegol...
#  decisao_operacional      | DECISÃO Nº 156
#  data_decisao_operacional | 05/11/2019
#  validade_operacional     | null
#  icao                     | GLO
#  iata                     | G3
# -RECORD 7----------------------------------------
#  razao_social             | MAP TRANSPORTES A...
#  cnpj                     | 10.483.635/0001-40
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AVENIDA SANTOS DU...
#  telefone                 | (92) 36521620
#  email                    | contabil@voemap.c...
#  decisao_operacional      | DECISÃO Nº 89
#  data_decisao_operacional | 14/08/2012
#  validade_operacional     | 17/08/2022
#  icao                     | PAM
#  iata                     | 7M
# -RECORD 8----------------------------------------
#  razao_social             | MODERN TRANSPORTE...
#  cnpj                     | 03.887.831/0001-15
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | AVENIDA PREFEITO ...
#  telefone                 | (21) 2272-9272 / ...
#  email                    | juridico@modern.c...
#  decisao_operacional      | DECISÃO Nº 79
#  data_decisao_operacional | 31/05/2017
#  validade_operacional     | 02/06/2027
#  icao                     | MWM
#  iata                     | WD
# -RECORD 9----------------------------------------
#  razao_social             | PASSAREDO TRANSPO...
#  cnpj                     | 00.512.777/0001-35
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | SETOR DE HANGARES...
#  telefone                 | (16) 3514-7127 / ...
#  email                    | juridico@voepass....
#  decisao_operacional      | DECISÃO Nº 105
#  data_decisao_operacional | 09/06/2020
#  validade_operacional     | null
#  icao                     | PTB
#  iata                     | 2Z
# -RECORD 10---------------------------------------
#  razao_social             | SIDERAL LINHAS AÉ...
#  cnpj                     | 10.919.908/0001-57
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | RODOVIA CONTORNO ...
#  telefone                 | (41) 3116-9000 / ...
#  email                    | office@siderallin...
#  decisao_operacional      | DECISÃO Nº 37
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | 06/03/2025
#  icao                     | SID
#  iata                     | 0S
# -RECORD 11---------------------------------------
#  razao_social             | TAM LINHAS AÉREAS...
#  cnpj                     | 02.012.862/0001-60
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | RUA ÁTICA , N° 67...
#  telefone                 | (11) 5582-8055 / ...
#  email                    | gar@tam.com.br
#  decisao_operacional      | DECISÃO Nº 366
#  data_decisao_operacional | 07/07/2021
#  validade_operacional     | 09/11/2031
#  icao                     | TAM
#  iata                     | JJ
# -RECORD 12---------------------------------------
#  razao_social             | TOTAL LINHAS AÉRE...
#  cnpj                     | 32.068.363/0001-55
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | AV. SENADOR SALGA...
#  telefone                 | (41) 3371-8200 / ...
#  email                    | geraldo.antonio@t...
#  decisao_operacional      | DECISÃO Nº 260
#  data_decisao_operacional | 12/01/2021
#  validade_operacional     | 14/01/2031
#  icao                     | TTL
#  iata                     | L1
# -RECORD 13---------------------------------------
#  razao_social             | AEROSUL TÁXI AÉRE...
#  cnpj                     | 27.315.694/0001-02
#  atividades_aereas        | SERVIÇOS AÉREOS P...
#  endereco_sede            | RODOVIA PR 218, K...
#  telefone                 | (43) 3176-4030
#  email                    | operacoes@aerosul...
#  decisao_operacional      | DECISÃO Nº 282
#  data_decisao_operacional | 10/02/2021
#  validade_operacional     | null
#  icao                     | ASO
#  iata                     | 2S
# -RECORD 14---------------------------------------
#  razao_social             | ATA - AEROTÁXI AB...
#  cnpj                     | 14.674.451/0001-19
#  atividades_aereas        | TÁXI-AÉREO, TRANS...
#  endereco_sede            |  PÇA. GAGO COUTIN...
#  telefone                 | (71) 34629600 / (...
#  email                    | guilherme@abaete....
#  decisao_operacional      | DECISÃO Nº 36
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | null
#  icao                     | ABJ
#  iata                     | null
# -RECORD 15---------------------------------------
#  razao_social             | OMNI TÁXI AÉREO S.A.
#  cnpj                     | 03.670.763/0001-38
#  atividades_aereas        | AEROFOTOGRAFIA, A...
#  endereco_sede            | AV. AYRTON SENNA,...
#  telefone                 | (61) 98335-3444
#  email                    | lira@plfconsultor...
#  decisao_operacional      | DECISÃO Nº 100
#  data_decisao_operacional | 10/07/2019
#  validade_operacional     | 12/07/2024
#  icao                     | OMI
#  iata                     | O1
# -RECORD 16---------------------------------------
#  razao_social             | PRIME TÁXI AIR LTDA
#  cnpj                     | 23.568.370/0001-25
#  atividades_aereas        | TÁXI-AÉREO, TRANS...
#  endereco_sede            | AL. RIO NEGRO, 58...
#  telefone                 | (11) 41958307 / (...
#  email                    | mmatta@primefract...
#  decisao_operacional      | DECISÃO Nº 237
#  data_decisao_operacional | 17/12/2020
#  validade_operacional     | 18/12/2025
#  icao                     | null
#  iata                     | null
# -RECORD 17---------------------------------------
#  razao_social             | SIDERAL LINHAS AÉ...
#  cnpj                     | 10.919.908/0001-57
#  atividades_aereas        | TRANSPORTE AÉREO ...
#  endereco_sede            | RODOVIA CONTORNO ...
#  telefone                 | (41) 3116-9000 / ...
#  email                    | office@siderallin...
#  decisao_operacional      | DECISÃO Nº 37
#  data_decisao_operacional | 05/03/2020
#  validade_operacional     | 06/03/2025
#  icao                     | SID
#  iata                     | 0S
# -RECORD 18---------------------------------------
#  razao_social             | RIMA - RIO MADEIR...
#  cnpj                     | 04.778.630/0001-42
#  atividades_aereas        | LIGAÇÃO AÉREA SIS...
#  endereco_sede            | AV. LAURO SODRÉ, ...
#  telefone                 | (69) 3225-8000
#  email                    | null
#  decisao_operacional      | DECISÃO Nº 116
#  data_decisao_operacional | 26/07/2017
#  validade_operacional     | 27/07/2022
#  icao                     | RIM
#  iata                     | 0R
# -RECORD 19---------------------------------------
#  razao_social             | RTS - ROTA DO SOL...
#  cnpj                     | 01.904.715/0001-31
#  atividades_aereas        | LIGAÇÃO AÉREA SIS...
#  endereco_sede            | PRAÇA EDUARDO GOM...
#  telefone                 | (85) 3272-3555
#  email                    | quadros@voerotado...
#  decisao_operacional      | DECISÃO Nº 21
#  data_decisao_operacional | 13/02/2019
#  validade_operacional     | 15/02/2024
#  icao                     | CKP
#  iata                     | null

# %%
df_vra.show(vertical=True)
# Out:
# -RECORD 0-------------------------------------
#  chegada_prevista       | 2021-01-19 14:45:00
#  chegada_real           | 2021-01-19 19:22:00
#  codigo_autorizacao     | 7
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBEG
#  icao_aerodromo_origem  | SBBE
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9702
#  partida_prevista       | 2021-01-19 12:35:00
#  partida_real           | 2021-01-19 17:17:00
#  situacao_voo           | REALIZADO
# -RECORD 1-------------------------------------
#  chegada_prevista       | 2021-01-26 12:05:00
#  chegada_real           | 2021-01-26 12:04:00
#  codigo_autorizacao     | 7
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBPA
#  icao_aerodromo_origem  | SBGL
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9701
#  partida_prevista       | 2021-01-26 10:00:00
#  partida_real           | 2021-01-26 09:55:00
#  situacao_voo           | REALIZADO
# -RECORD 2-------------------------------------
#  chegada_prevista       | 2021-01-18 23:20:00
#  chegada_real           | 2021-01-19 00:50:00
#  codigo_autorizacao     | 7
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBBE
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9701
#  partida_prevista       | 2021-01-18 21:15:00
#  partida_real           | 2021-01-18 22:35:00
#  situacao_voo           | REALIZADO
# -RECORD 3-------------------------------------
#  chegada_prevista       | 2021-01-15 00:45:00
#  chegada_real           | 2021-01-15 00:39:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBEG
#  icao_aerodromo_origem  | SBGL
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9700
#  partida_prevista       | 2021-01-14 20:30:00
#  partida_real           | 2021-01-14 20:27:00
#  situacao_voo           | REALIZADO
# -RECORD 4-------------------------------------
#  chegada_prevista       | 2021-01-24 15:10:00
#  chegada_real           | 2021-01-24 23:21:00
#  codigo_autorizacao     | 7
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBEG
#  icao_aerodromo_origem  | SBKP
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9700
#  partida_prevista       | 2021-01-24 11:30:00
#  partida_real           | 2021-01-24 19:35:00
#  situacao_voo           | REALIZADO
# -RECORD 5-------------------------------------
#  chegada_prevista       | 2021-01-15 17:55:00
#  chegada_real           | 2021-01-15 18:00:00
#  codigo_autorizacao     | 2
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9203
#  partida_prevista       | 2021-01-15 14:00:00
#  partida_real           | 2021-01-15 14:05:00
#  situacao_voo           | REALIZADO
# -RECORD 6-------------------------------------
#  chegada_prevista       | 2021-01-30 15:35:00
#  chegada_real           | 2021-01-30 15:16:00
#  codigo_autorizacao     | 2
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9203
#  partida_prevista       | 2021-01-30 11:40:00
#  partida_real           | 2021-01-30 11:25:00
#  situacao_voo           | REALIZADO
# -RECORD 7-------------------------------------
#  chegada_prevista       | 2021-01-23 19:10:00
#  chegada_real           | 2021-01-23 19:31:00
#  codigo_autorizacao     | 2
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBBR
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 9203
#  partida_prevista       | 2021-01-23 16:10:00
#  partida_real           | 2021-01-23 16:36:00
#  situacao_voo           | REALIZADO
# -RECORD 8-------------------------------------
#  chegada_prevista       | 2021-01-14 14:40:00
#  chegada_real           | 2021-01-14 14:50:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBRF
#  icao_aerodromo_origem  | SBKP
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5806
#  partida_prevista       | 2021-01-14 11:30:00
#  partida_real           | 2021-01-14 11:42:00
#  situacao_voo           | REALIZADO
# -RECORD 9-------------------------------------
#  chegada_prevista       | 2021-01-12 14:10:00
#  chegada_real           | 2021-01-12 14:48:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBRF
#  icao_aerodromo_origem  | SBKP
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5806
#  partida_prevista       | 2021-01-12 11:00:00
#  partida_real           | 2021-01-12 11:21:00
#  situacao_voo           | REALIZADO
# -RECORD 10------------------------------------
#  chegada_prevista       | 2021-01-07 14:10:00
#  chegada_real           | 2021-01-07 14:18:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBRF
#  icao_aerodromo_origem  | SBKP
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5806
#  partida_prevista       | 2021-01-07 11:00:00
#  partida_real           | 2021-01-07 11:00:00
#  situacao_voo           | REALIZADO
# -RECORD 11------------------------------------
#  chegada_prevista       | 2021-01-05 14:10:00
#  chegada_real           | 2021-01-05 14:51:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBRF
#  icao_aerodromo_origem  | SBKP
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5806
#  partida_prevista       | 2021-01-05 11:00:00
#  partida_real           | 2021-01-05 11:35:00
#  situacao_voo           | REALIZADO
# -RECORD 12------------------------------------
#  chegada_prevista       | 2021-01-28 12:45:00
#  chegada_real           | 2021-01-28 12:52:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-28 08:50:00
#  partida_real           | 2021-01-28 08:56:00
#  situacao_voo           | REALIZADO
# -RECORD 13------------------------------------
#  chegada_prevista       | 2021-01-23 10:15:00
#  chegada_real           | 2021-01-23 10:19:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-23 06:20:00
#  partida_real           | 2021-01-23 06:26:00
#  situacao_voo           | REALIZADO
# -RECORD 14------------------------------------
#  chegada_prevista       | 2021-01-19 09:45:00
#  chegada_real           | 2021-01-19 09:30:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-19 02:50:00
#  partida_real           | 2021-01-19 05:41:00
#  situacao_voo           | REALIZADO
# -RECORD 15------------------------------------
#  chegada_prevista       | 2021-01-14 09:45:00
#  chegada_real           | 2021-01-14 09:32:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-14 05:50:00
#  partida_real           | 2021-01-14 05:46:00
#  situacao_voo           | REALIZADO
# -RECORD 16------------------------------------
#  chegada_prevista       | 2021-01-05 08:05:00
#  chegada_real           | 2021-01-05 07:45:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBKP
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-05 04:10:00
#  partida_real           | 2021-01-05 03:57:00
#  situacao_voo           | REALIZADO
# -RECORD 17------------------------------------
#  chegada_prevista       | 2021-01-30 11:50:00
#  chegada_real           | 2021-01-30 11:53:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBBR
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-30 08:50:00
#  partida_real           | 2021-01-30 08:41:00
#  situacao_voo           | REALIZADO
# -RECORD 18------------------------------------
#  chegada_prevista       | 2021-01-26 11:50:00
#  chegada_real           | 2021-01-26 11:40:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBBR
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-26 08:50:00
#  partida_real           | 2021-01-26 08:42:00
#  situacao_voo           | REALIZADO
# -RECORD 19------------------------------------
#  chegada_prevista       | 2021-01-21 06:50:00
#  chegada_real           | 2021-01-21 06:50:00
#  codigo_autorizacao     | 0
#  codigo_justificativa   | N/A
#  codigo_tipo_linha      | C
#  icao_aerodromo_destino | SBBR
#  icao_aerodromo_origem  | SBEG
#  icao_empresa_aerea     | MWM
#  numero_voo             | 5803
#  partida_prevista       | 2021-01-21 03:50:00
#  partida_real           | 2021-01-21 03:52:00
#  situacao_voo           | REALIZADO
# only showing top 20 rows

# %%
df_aerodromos.show(vertical=True)
# Out:
# -RECORD 0-----------------------------
#  id            | 6811
#  iata          | SJK
#  icao          | SBSJ
#  name          | Professor Urbano ...
#  location      | São José dos Camp...
#  street_number | 1941
#  street        | Avenida Brigadeir...
#  city          |
#  county        | São José dos Campos
#  state         | São Paulo
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 12227-000
#  phone         | +55 12 3946-3000
#  latitude      | -23.225304
#  longitude     | -45.861576
#  uct           | -180
#  website       | http://www.infrae...
# -RECORD 1-----------------------------
#  id            | 7410
#  iata          | TJL
#  icao          | SBTG
#  name          | Plínio Alarcom Ai...
#  location      | Três Lagoas, Mato...
#  street_number |
#  street        | Avenida Antônio T...
#  city          |
#  county        | Três Lagoas
#  state         | Mato Grosso do Sul
#  country_iso   | BR
#  country       | Brazil
#  postal_code   |
#  phone         |
#  latitude      | -20.753672
#  longitude     | -51.68211
#  uct           | -240
#  website       |
# -RECORD 2-----------------------------
#  id            | 5771
#  iata          | PAN
#  icao          | VTSK
#  name          | Pattani Airport
#  location      | Pattani, Thailand
#  street_number |
#  street        |
#  city          | Bo Thong
#  county        | Nong Chik District
#  state         | Pattani
#  country_iso   | TH
#  country       | Thailand
#  postal_code   | 94170
#  phone         | +66 73 341 301
#  latitude      | 6.7860346
#  longitude     | 101.15174
#  uct           | 420
#  website       | http://minisite.a...
# -RECORD 3-----------------------------
#  id            | 2754
#  iata          | GUZ
#  icao          | SNGA
#  name          | Guarapari Airport
#  location      | Guarapari, Espíri...
#  street_number | 187
#  street        | Avenida Padre Jos...
#  city          |
#  county        | Guarapari
#  state         | Espírito Santo
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 29215-250
#  phone         | +55 27 3361-2813
#  latitude      | -20.647001
#  longitude     | -40.490875
#  uct           | -180
#  website       |
# -RECORD 4-----------------------------
#  id            | 393
#  iata          | ASU
#  icao          | SGAS
#  name          | Silvio Pettirossi...
#  location      | Asunción, Paraguay
#  street_number |
#  street        | Autopista Silvio ...
#  city          | Luque
#  county        |
#  state         | Departamento Central
#  country_iso   | PY
#  country       | Paraguay
#  postal_code   |
#  phone         | +595 21 688 2000
#  latitude      | -25.241512
#  longitude     | -57.514183
#  uct           | -180
#  website       | http://www.dinac....
# -RECORD 5-----------------------------
#  id            | 5861
#  iata          | PET
#  icao          | SBPK
#  name          | João Simões Lopes...
#  location      | Pelotas, Rio Gran...
#  street_number | S/n
#  street        | Avenida Zeferino ...
#  city          |
#  county        | Pelotas
#  state         | Rio Grande do Sul
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 96070-480
#  phone         | +55 53 3223-1227
#  latitude      | -31.715822
#  longitude     | -52.33069
#  uct           | -180
#  website       | http://www.infrae...
# -RECORD 6-----------------------------
#  id            | 1629
#  iata          | CXJ
#  icao          | SBCX
#  name          | Caxias do Sul Air...
#  location      | Caxias do Sul, Ri...
#  street_number | 3451
#  street        | Avenida Salgado F...
#  city          |
#  county        | Caxias do Sul
#  state         | Rio Grande do Sul
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 95098-420
#  phone         | +55 54 3901-1219
#  latitude      | -29.19492
#  longitude     | -51.18693
#  uct           | -180
#  website       | http://www.transp...
# -RECORD 7-----------------------------
#  id            | 1373
#  iata          | CKY
#  icao          | GUCY
#  name          | Conakry Internati...
#  location      | Conakry, Guinea
#  street_number |
#  street        | N1
#  city          | Conakry
#  county        |
#  state         | Conakry
#  country_iso   | GN
#  country       | Guinea
#  postal_code   |
#  phone         | +224 627 09 95 57
#  latitude      | 9.575655
#  longitude     | -13.62017
#  uct           | 0
#  website       | http://www.aeropo...
# -RECORD 8-----------------------------
#  id            | 6154
#  iata          | PUC
#  icao          | KPUC
#  name          | Carbon County Reg...
#  location      | Price, Utah, Unit...
#  street_number | 3095
#  street        | Airport Road
#  city          | Price
#  county        | Carbon County
#  state         | Utah
#  country_iso   | US
#  country       | United States
#  postal_code   | 84501
#  phone         | +1 435-637-9556
#  latitude      | 39.61092
#  longitude     | -110.752785
#  uct           | -360
#  website       | http://redtailfbo...
# -RECORD 9-----------------------------
#  id            | 7204
#  iata          | SZX
#  icao          | ZGSZ
#  name          | Shenzhen Bao'an I...
#  location      | Shenzhen, Guangdo...
#  street_number |
#  street        |
#  city          | Shenzhen
#  county        |
#  state         | Guangdong
#  country_iso   | CN
#  country       | China
#  postal_code   |
#  phone         | +86 755 2345 6789
#  latitude      | 22.636827
#  longitude     | 113.814606
#  uct           | 480
#  website       | http://www.szairp...
# -RECORD 10----------------------------
#  id            | 7359
#  iata          | THE
#  icao          | SBTE
#  name          | Teresina–Senador ...
#  location      | Teresina, Piauí, ...
#  street_number |
#  street        |
#  city          |
#  county        | Teresina
#  state         | Piauí
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 64006-700
#  phone         | +55 86 3133-6270
#  latitude      | -5.063463
#  longitude     | -42.82119
#  uct           | -180
#  website       | http://www4.infra...
# -RECORD 11----------------------------
#  id            | 6054
#  iata          | PPB
#  icao          | SBDN
#  name          | Presidente Pruden...
#  location      | Presidente Pruden...
#  street_number | s/nº
#  street        | Assis Chateaubria...
#  city          |
#  county        | Presidente Prudente
#  state         | São Paulo
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 19053-680
#  phone         | +55 18 3222-8099
#  latitude      | -22.17834
#  longitude     | -51.417664
#  uct           | -180
#  website       | http://www.daesp....
# -RECORD 12----------------------------
#  id            | 2787
#  iata          | GYN
#  icao          | SBGO
#  name          | Santa Genoveva Ai...
#  location      | Goiânia, Goiás, B...
#  street_number | s/n
#  street        | Alameda 4
#  city          |
#  county        | Goiânia
#  state         | Goiás
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 74672-410
#  phone         | +55 62 3265-1500
#  latitude      | -16.632303
#  longitude     | -49.216347
#  uct           | -180
#  website       | http://www4.infra...
# -RECORD 13----------------------------
#  id            | 3473
#  iata          | JPA
#  icao          | SBJP
#  name          | Presidente Castro...
#  location      | João Pessoa, Para...
#  street_number | s/n
#  street        | Aeroporto Interna...
#  city          |
#  county        | João Pessoa
#  state         | Paraíba
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 58308-901
#  phone         | +55 83 3041-4200
#  latitude      | -7.146009
#  longitude     | -34.948776
#  uct           | -180
#  website       | http://www4.infra...
# -RECORD 14----------------------------
#  id            | 2732
#  iata          | GUA
#  icao          | MGGT
#  name          | La Aurora Interna...
#  location      | Guatemala City, G...
#  street_number |
#  street        |
#  city          | Guatemala City
#  county        |
#  state         | Guatemala Department
#  country_iso   | GT
#  country       | Guatemala
#  postal_code   |
#  phone         | +502 2321 5000
#  latitude      | 14.584098
#  longitude     | -90.52769
#  uct           | -360
#  website       | http://www.dgac.g...
# -RECORD 15----------------------------
#  id            | 5685
#  iata          | OST
#  icao          | EBOS
#  name          | Ostend–Bruges Int...
#  location      | Ostend / Bruges, ...
#  street_number | 889
#  street        | Nieuwpoortsesteenweg
#  city          | Oostende
#  county        | West-Vlaanderen
#  state         | Vlaanderen
#  country_iso   | BE
#  country       | Belgium
#  postal_code   | 8400
#  phone         | +32 59 55 12 11
#  latitude      | 51.204193
#  longitude     | 2.8698127
#  uct           | 120
#  website       | http://www.luchth...
# -RECORD 16----------------------------
#  id            | 3166
#  iata          | IGU
#  icao          | SBFI
#  name          | Foz do Iguaçu Int...
#  location      | Foz do Iguaçu, Pa...
#  street_number |
#  street        |
#  city          |
#  county        | Foz do Iguaçu
#  state         | Paraná
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 85863-900
#  phone         | +55 45 3521-4200
#  latitude      | -25.59771
#  longitude     | -54.488514
#  uct           | -180
#  website       | http://www4.infra...
# -RECORD 17----------------------------
#  id            | 337
#  iata          | APX
#  icao          | SSOG
#  name          | Arapongas Airport
#  location      | Arapongas, Paraná...
#  street_number | 217
#  street        | PR-218
#  city          |
#  county        | Sabáudia
#  state         | Paraná
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 86720-000
#  phone         | +55 43 3274-9122
#  latitude      | -23.352522
#  longitude     | -51.491943
#  uct           | -180
#  website       |
# -RECORD 18----------------------------
#  id            | 4435
#  iata          | LVR
#  icao          | SILC
#  name          | Bom Futuro Munici...
#  location      | Lucas do Rio Verd...
#  street_number | s/n
#  street        | Rod MT-449 KM 4
#  city          |
#  county        | Lucas do Rio Verde
#  state         | Mato Grosso
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 78455-000
#  phone         |
#  latitude      | -13.034962
#  longitude     | -55.942123
#  uct           | -240
#  website       |
# -RECORD 19----------------------------
#  id            | 2279
#  iata          | FEN
#  icao          | SBFN
#  name          | Fernando de Noron...
#  location      | Fernando de Noron...
#  street_number |
#  street        |
#  city          |
#  county        | Fernando de Noronha
#  state         | State of Pernambuco
#  country_iso   | BR
#  country       | Brazil
#  postal_code   | 53990-000
#  phone         |
#  latitude      | -3.8546145
#  longitude     | -32.424385
#  uct           | -120
#  website       |
# only showing top 20 rows
